# %% [markdown]
# A program For Photographers Event <br>
# Introduction <br>
# ABC is a company based in Toronto for organizing events, currently it works on a project to organize an event for 5 days for a group of photographers from all over the world.The company has to put a good program, including a hotel of residence, a hall for meetings, places of landscape to visit, stores for shopping, restaurants and cafes. So the company’s purpose is to make a list of places of landscape in Toronto, including the nearest restaurants, cafes, and shopping stores for each place.
#
# Data Description <br>
# The data used in this project is provided by Foursquare location data. The data are grouped by landscape area, and each area included the information about this area and all information about restaurants, cafes, and stores which in this area.
#
# Table of contents <br>
# 01- Import Libraries <br>
# 02- Define Foursquare Credentials <br>
# 03- Define the city and get its latitude & longitude <br>
# 04- Search for Hotels & clean dataframe <br>
# 05- Search for Parks & clean dataframe <br>
# 06- Search for Restaurants & clean dataframe <br>
# 07- Search for Cafeteria & clean dataframe <br>
# 08- Search for Shopping Stores & clean dataframe <br>
# 09- Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together <br>
# 10- Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together <br>

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Mandeep\Anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.11.28 |       hecc5488_0         182 KB  conda-forge
#     certifi-2019.11.28         |           py37_0         148 KB  conda-forge
#     conda-4.8.0                |           py37_1         3.0 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     openssl-1.1.1d             |       hfa6e2cd_0         4.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.20.0-py_0
#
# The following packages will be UPDATED:
#
#   ca-certificates     anaconda::ca-certificates-2019.8.28-0 --> conda-forge::ca-certificates-2019.11.28-hecc5488_0
#   certifi                anaconda::certifi-2019.9.11-py37_0 --> conda-forge::certifi-2019.11.28-py37_0
#   conda                       anaconda::conda-4.7.12-py37_0 --> conda-forge::conda-4.8.0-py37_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   openssl                anaconda::openssl-1.1.1-he774522_0 --> conda-forge::openssl-1.1.1d-hfa6e2cd_0
#
#
#
# Downloading and Extracting Packages
#
# ca-certificates-2019 | 182 KB    |            |   0%
# ca-certificates-2019 | 182 KB    | 8          |   9%
# ca-certificates-2019 | 182 KB    | #########6 |  96%
# ca-certificates-2019 | 182 KB    | ########## | 100%
#
# openssl-1.1.1d       | 4.7 MB    |            |   0%
# openssl-1.1.1d       | 4.7 MB    |            |   1%
# openssl-1.1.1d       | 4.7 MB    | 4          |   5%
# openssl-1.1.1d       | 4.7 MB    | 8          |   8%
# openssl-1.1.1d       | 4.7 MB    | #1         |  12%
# openssl-1.1.1d       | 4.7 MB    | #4         |  15%
# openssl-1.1.1d       | 4.7 MB    | #7         |  18%
# openssl-1.1.1d       | 4.7 MB    | ##         |  20%
# openssl-1.1.1d       | 4.7 MB    | ##2        |  23%
# openssl-1.1.1d       | 4.7 MB    | ##5        |  26%
# openssl-1.1.1d       | 4.7 MB    | ##8        |  29%
# openssl-1.1.1d       | 4.7 MB    | ###1       |  31%
# openssl-1.1.1d       | 4.7 MB    | ###3       |  34%
# openssl-1.1.1d       | 4.7 MB    | ###6       |  37%
# openssl-1.1.1d       | 4.7 MB    | ###8       |  39%
# openssl-1.1.1d       | 4.7 MB    | ####3      |  43%
# openssl-1.1.1d       | 4.7 MB    | ####6      |  46%
# openssl-1.1.1d       | 4.7 MB    | ####9      |  49%
# openssl-1.1.1d       | 4.7 MB    | #####3     |  53%
# openssl-1.1.1d       | 4.7 MB    | #####6     |  57%
# openssl-1.1.1d       | 4.7 MB    | ######     |  60%
# openssl-1.1.1d       | 4.7 MB    | ######3    |  63%
# openssl-1.1.1d       | 4.7 MB    | ######6    |  67%
# openssl-1.1.1d       | 4.7 MB    | ######9    |  70%
# openssl-1.1.1d       | 4.7 MB    | #######2   |  72%
# openssl-1.1.1d       | 4.7 MB    | #######4   |  75%
# openssl-1.1.1d       | 4.7 MB    | #######6   |  77%
# openssl-1.1.1d       | 4.7 MB    | #######8   |  78%
# openssl-1.1.1d       | 4.7 MB    | ########   |  80%
# openssl-1.1.1d       | 4.7 MB    | ########1  |  82%
# openssl-1.1.1d       | 4.7 MB    | ########3  |  83%
# openssl-1.1.1d       | 4.7 MB    | ########4  |  84%
# openssl-1.1.1d       | 4.7 MB    | ########6  |  86%
# openssl-1.1.1d       | 4.7 MB    | #########  |  90%
# openssl-1.1.1d       | 4.7 MB    | #########3 |  94%
# openssl-1.1.1d       | 4.7 MB    | #########7 |  97%
# openssl-1.1.1d       | 4.7 MB    | ########## | 100%
#
# geopy-1.20.0         | 57 KB     |            |   0%
# geopy-1.20.0         | 57 KB     | #####5     |  56%
# geopy-1.20.0         | 57 KB     | ########## | 100%
#
# conda-4.8.0          | 3.0 MB    |            |   0%
# conda-4.8.0          | 3.0 MB    | 1          |   1%
# conda-4.8.0          | 3.0 MB    | 6          |   7%
# conda-4.8.0          | 3.0 MB    | #2         |  12%
# conda-4.8.0          | 3.0 MB    | #7         |  17%
# conda-4.8.0          | 3.0 MB    | ##2        |  23%
# conda-4.8.0          | 3.0 MB    | ##6        |  27%
# conda-4.8.0          | 3.0 MB    | ###2       |  32%
# conda-4.8.0          | 3.0 MB    | ###8       |  38%
# conda-4.8.0          | 3.0 MB    | ####3      |  43%
# conda-4.8.0          | 3.0 MB    | ####8      |  48%
# conda-4.8.0          | 3.0 MB    | #####3     |  53%
# conda-4.8.0          | 3.0 MB    | #####9     |  59%
# conda-4.8.0          | 3.0 MB    | ######5    |  65%
# conda-4.8.0          | 3.0 MB    | #######    |  70%
# conda-4.8.0          | 3.0 MB    | #######5   |  76%
# conda-4.8.0          | 3.0 MB    | ########   |  81%
# conda-4.8.0          | 3.0 MB    | ########5  |  86%
# conda-4.8.0          | 3.0 MB    | #########  |  91%
# conda-4.8.0          | 3.0 MB    | #########4 |  95%
# conda-4.8.0          | 3.0 MB    | #########8 |  99%
# conda-4.8.0          | 3.0 MB    | ########## | 100%
#
# geographiclib-1.50   | 34 KB     |            |   0%
# geographiclib-1.50   | 34 KB     | ########## | 100%
#
# certifi-2019.11.28   | 148 KB    |            |   0%
# certifi-2019.11.28   | 148 KB    | ####3      |  43%
# certifi-2019.11.28   | 148 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
ClIENT_ID = '4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0' # your Foursquare ID
ClIENT_SECRET = 'RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: 4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0
# Foursquare_Secret:RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ

# %%
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '56aa371be4b08b9a8d5734cf', 'name': 'B...    False
#
#                          id       location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3  123 Queen Street West          CA       Toronto
# 1  4b68aed1f964a520de862be3         194 Queen St W          CA       Toronto
# 2  52ce14b0498e50457ce11780    108 Chestnut Street          CA       Toronto
# 3  4f343a31e4b0230a3b337a90         123 Test Drive          CA       Toronto
# 4  5545d07e498e2facac03f666  123 Queen Street West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                390
# 1           Canada  Queen & St. Patrick                400
# 2           Canada          Dundas St W                124
# 3           Canada      at somewhere St                500
# 4           Canada        at Bay Street                376
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [108 Chestnut Street (Dundas St W), Toronto ON...
# 3  [123 Test Drive (at somewhere St), Toronto ON ...
# 4  [123 Queen Street West (at Bay Street), Toront...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.6511441, 'lng'...     43.651144
# 1  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
# 2  [{'label': 'display', 'lat': 43.6546083, 'lng'...     43.654608
# 3  [{'label': 'display', 'lat': 43.658434, 'lng':...     43.658434
# 4  [{'label': 'display', 'lat': 43.65119976208405...     43.651200
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.384329                   NaN             M5H 2M9             ON
# 1    -79.388577                   NaN             M5V 1Z1             ON
# 2    -79.385942                   NaN             M5G 1R3             ON
# 3    -79.387894                   NaN             M2M 2M2             ON
# 4    -79.384520    Financial District                 NaN             ON
#
#                                              name    referralId venuePage.id
# 0                   Sheraton Centre Toronto Hotel  v-1577761022          NaN
# 1                  The Rex Hotel Jazz & Blues Bar  v-1577761022     62225795
# 2     DoubleTree by Hilton Hotel Toronto Downtown  v-1577761022          NaN
# 3                                  VFM Test Hotel  v-1577761022          NaN
# 4  Sheraton Centre Toronto Hotel - Grand Ballroom  v-1577761022          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                              name categories  \
# 0                   Sheraton Centre Toronto Hotel      Hotel
# 1                  The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2     DoubleTree by Hilton Hotel Toronto Downtown      Hotel
# 3                                  VFM Test Hotel      Hotel
# 4  Sheraton Centre Toronto Hotel - Grand Ballroom   Ballroom
#
#                  address  cc     city country          crossStreet  distance  \
# 0  123 Queen Street West  CA  Toronto  Canada          at York St.       390
# 1         194 Queen St W  CA  Toronto  Canada  Queen & St. Patrick       400
# 2    108 Chestnut Street  CA  Toronto  Canada          Dundas St W       124
# 3         123 Test Drive  CA  Toronto  Canada      at somewhere St       500
# 4  123 Queen Street West  CA  Toronto  Canada        at Bay Street       376
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [108 Chestnut Street (Dundas St W), Toronto ON...
# 3  [123 Test Drive (at somewhere St), Toronto ON ...
# 4  [123 Queen Street West (at Bay Street), Toront...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.6511441, 'lng'...  43.651144 -79.384329
# 1  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
# 2  [{'label': 'display', 'lat': 43.6546083, 'lng'...  43.654608 -79.385942
# 3  [{'label': 'display', 'lat': 43.658434, 'lng':...  43.658434 -79.387894
# 4  [{'label': 'display', 'lat': 43.65119976208405...  43.651200 -79.384520
#
#          neighborhood postalCode state                        id
# 0                 NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1                 NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 2                 NaN    M5G 1R3    ON  52ce14b0498e50457ce11780
# 3                 NaN    M2M 2M2    ON  4f343a31e4b0230a3b337a90
# 4  Financial District        NaN    ON  5545d07e498e2facac03f666

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2      DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 3                                   VFM Test Hotel                   Hotel
# 4   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 5                                  Stathcona Hotel                   Hotel
# 6                Sheraton Centre Hotel Club Lounge                  Lounge
# 7    hilton hotel, richmondstreet E, 145,  toronto              Hotel Pool
# 8                                Be SixFifty Hotel                   Hotel
# 9                                        650 Hotel                   Hotel
# 10                              Shangri-La Toronto                   Hotel
# 11                                  Hilton Toronto                   Hotel
# 12                           89 Chestnut Residence  College Residence Hall
# 13    Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 14                   Op mijn hotelkamer In Toronto                   Hotel
# 15          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 16                                  Fitness Centre                     Gym
# 17                                  Fitness Centre                     Gym
# 18                                            Pool                    Pool
# 19                                   Bistro on Two          Breakfast Spot
# 20                                   Kumar For Men             Men's Store
# 21                                  Grand Ballroom             Event Space
#
#                   address        lat        lng postalCode    state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9       ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 4   123 Queen Street West  43.651200 -79.384520        NaN       ON
# 5                     NaN  43.654947 -79.386359        NaN       ON
# 6                     NaN  43.651063 -79.384527    M5H 2M9       ON
# 7   Richmondstreet E, 145  43.650625 -79.385488        NaN       ON
# 8          650 Bay Street  43.657120 -79.384560        NaN       ON
# 9          650 Bay Street  43.657046 -79.384411        NaN       ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 11      145 Richmond St W  43.649946 -79.385479    M5H 2L2       ON
# 12        89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 13         525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 14                    NaN  43.654235 -79.386208        NaN       ON
# 15    188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 16        Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON
# 17            525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 18       Intercontinental  43.650975 -79.384053        NaN  Ontario
# 19        123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON
# 20        Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2    DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 3                                 VFM Test Hotel                   Hotel
# 10                            Shangri-La Toronto                   Hotel
# 11                                Hilton Toronto                   Hotel
# 12                         89 Chestnut Residence  College Residence Hall
# 13  Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 15        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 16                                Fitness Centre                     Gym
# 17                                Fitness Centre                     Gym
# 19                                 Bistro on Two          Breakfast Spot
# 20                                 Kumar For Men             Men's Store
# 21                                Grand Ballroom             Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 12        89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 13         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 15    188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 16        Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON
# 17            525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 19        123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON
# 20        Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 3                                 VFM Test Hotel        Hotel
# 10                            Shangri-La Toronto        Hotel
# 11                                Hilton Toronto        Hotel
# 13  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 21                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 13         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 3                                 VFM Test Hotel        Hotel
# 10                            Shangri-La Toronto        Hotel
# 11                                Hilton Toronto        Hotel
# 13  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 21                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 13         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 21                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.651144 -79.384329    M5H 2M9    ON
# 21  43.651217 -79.383771    M5H 2M9    ON

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
#
#                          id          location.address location.cc  \
# 0  4b170e47f964a5208cc123e3        691 University Ave          CA
# 1  4b54deadf964a520a3d027e3                       NaN          CA
# 2  4d3a1d23325ff04db2dd1845               763 Bay St.          CA
# 3  4bfc5019da7120a132df49fd  450 Adelaide Street West          CA
# 4  4bb79860cf2fc9b616779e02    35 Wellington St. East          CA
#
#   location.city location.country               location.crossStreet  \
# 0       Toronto           Canada                      at College St
# 1       Toronto           Canada                                NaN
# 2       Toronto           Canada  btwn. College St. and Gerrard St.
# 3       Toronto           Canada           Brant St & Adelaide St W
# 4       Toronto           Canada                                NaN
#
#    location.distance                          location.formattedAddress  \
# 0                716  [691 University Ave (at College St), Toronto O...
# 1                423  [btwn College, University, Queen & Spadina, To...
# 2                672  [763 Bay St. (btwn. College St. and Gerrard St...
# 3               1183  [450 Adelaide Street West (Brant St & Adelaide...
# 4               1171       [35 Wellington St. East, Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 1  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 2  [{'label': 'display', 'lat': 43.65982157793473...     43.659822
# 3  [{'label': 'display', 'lat': 43.64738759338116...     43.647388
# 4  [{'label': 'display', 'lat': 43.64804835388851...     43.648048
#
#    location.lng location.postalCode location.state  \
# 0    -79.390272             M5G 2P1             ON
# 1    -79.392053                 NaN             ON
# 2    -79.385159             M5G 2R3             ON
# 3    -79.398752                 NaN             ON
# 4    -79.375172                 NaN             ON
#
#                                 name    referralId venuePage.id
# 0        Queen's Park Subway Station  v-1577761164          NaN
# 1                        Grange Park  v-1577761164          NaN
# 2   Residences at College Park North  v-1577761164          NaN
# 3  St. Andrews Playground / Dog Park  v-1577761164          NaN
# 4                        Berczy Park  v-1577761164          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                                 name  \
# 0        Queen's Park Subway Station
# 1                        Grange Park
# 2   Residences at College Park North
# 3  St. Andrews Playground / Dog Park
# 4                        Berczy Park
#
#                                  categories                   address  cc  \
# 0                             Metro Station        691 University Ave  CA
# 1                                      Park                       NaN  CA
# 2  Residential Building (Apartment / Condo)               763 Bay St.  CA
# 3                                      Park  450 Adelaide Street West  CA
# 4                                      Park    35 Wellington St. East  CA
#
#       city country                        crossStreet  distance  \
# 0  Toronto  Canada                      at College St       716
# 1  Toronto  Canada                                NaN       423
# 2  Toronto  Canada  btwn. College St. and Gerrard St.       672
# 3  Toronto  Canada           Brant St & Adelaide St W      1183
# 4  Toronto  Canada                                NaN      1171
#
#                                     formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [763 Bay St. (btwn. College St. and Gerrard St...
# 3  [450 Adelaide Street West (Brant St & Adelaide...
# 4       [35 Wellington St. East, Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 1  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 2  [{'label': 'display', 'lat': 43.65982157793473...  43.659822 -79.385159
# 3  [{'label': 'display', 'lat': 43.64738759338116...  43.647388 -79.398752
# 4  [{'label': 'display', 'lat': 43.64804835388851...  43.648048 -79.375172
#
#   postalCode state                        id
# 0    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 1        NaN    ON  4b54deadf964a520a3d027e3
# 2    M5G 2R3    ON  4d3a1d23325ff04db2dd1845
# 3        NaN    ON  4bfc5019da7120a132df49fd
# 4        NaN    ON  4bb79860cf2fc9b616779e02

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                        name  \
# 0               Queen's Park Subway Station
# 1                               Grange Park
# 2          Residences at College Park North
# 3         St. Andrews Playground / Dog Park
# 4                               Berczy Park
# 5             Crunch Fitness - College Park
# 6                              Queen's Park
# 7                             One Park Lane
# 8        TTC Streetcar #403 - Victoria park
# 9                      Clarence Square Park
# 10                   Physiomed College Park
# 11                   Trinity Bellwoods Park
# 12                  St Lawrence on the Park
# 13  GoodLife Fitness Toronto Bloor and Park
# 14                     Bellevue Square Park
# 15         Toothworks - College Park Dental
# 16                  Stanley Park (Dog Park)
# 17                      RBC WaterPark Place
# 18                                 HTO Park
# 19                       Canoe Landing Park
# 20                             College Park
# 21                       Battery Park Tower
# 22                              Regent Park
# 23                  Moss Park Tennis Courts
# 24                   Parliament Square Park
# 25                      Riverdale Park East
# 26                      Riverdale Park West
# 27                        Osgoode Hall Park
# 28             Regent Park Community Centre
# 29                        Barbara Hall Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2   Residential Building (Apartment / Condo)                   763 Bay St.
# 3                                       Park      450 Adelaide Street West
# 4                                       Park        35 Wellington St. East
# 5                       Gym / Fitness Center              382 Yonge Street
# 6                                       Park               University Ave.
# 7   Residential Building (Apartment / Condo)                 280 Simcoe St
# 8                         Light Rail Station                           NaN
# 9                                       Park                   Spadina Ave
# 10                            Medical Center                  382 Yonge St
# 11                                      Park            1053 Dundas St. W.
# 12                                  Building               65 Scadding Ave
# 13                                       Gym                     8 Park Rd
# 14                                      Park  btwn Bellevue & Augusta Ave.
# 15                          Dentist's Office        444 Yonge St, Unit M16
# 16                                   Dog Run              King Street West
# 17                                    Office                88 Queens Quay
# 18                                      Park                  Queen's Quay
# 19                                      Park             50 Fort York Blvd
# 20                             Shopping Mall                  444 Yonge St
# 21  Residential Building (Apartment / Condo)           50 Lynn Williams St
# 22                              Neighborhood                           NaN
# 23                              Tennis Court                     Moss Park
# 24                                      Park          44 Parliament Street
# 25                                      Park             550 Broadview Ave
# 26                                      Park               500 Gerrard St.
# 27                                      Park                130 Queen St W
# 28                          Community Center               465 Dundas St E
# 29                                      Park             519 Church Street
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.659822 -79.385159    M5G 2R3    ON
# 3   43.647388 -79.398752        NaN    ON
# 4   43.648048 -79.375172        NaN    ON
# 5   43.659263 -79.382632    M5G 1S8    ON
# 6   43.663946 -79.392180    M5R 2E8    ON
# 7   43.655442 -79.390056    M5T 2Y5    ON
# 8   43.650735 -79.386921        NaN    ON
# 9   43.644222 -79.394230        NaN    ON
# 10  43.659240 -79.382860    M5B 1S8    ON
# 11  43.647072 -79.413756    M5H 2N2    ON
# 12  43.648963 -79.364868        NaN    ON
# 13  43.671302 -79.384691    M4W 3G8    ON
# 14  43.653610 -79.402199    M5T 2N4    ON
# 15  43.660009 -79.383905        NaN    ON
# 16  43.641668 -79.409269        NaN    ON
# 17  43.641075 -79.379154        NaN    ON
# 18  43.637949 -79.387820        NaN    ON
# 19  43.638762 -79.397067    M5V 3Z1    ON
# 20  43.661237 -79.383603    M5B 2H4    ON
# 21  43.639024 -79.415510    M6K 3R9    ON
# 22  43.660009 -79.364191        NaN    ON
# 23  43.655337 -79.371923        NaN    ON
# 24  43.650264 -79.362195        NaN    ON
# 25  43.669951 -79.355493    M4K 2P1    ON
# 26  43.666048 -79.360941    M5A 2H3    ON
# 27  43.651105 -79.386269    M5H 2N5    ON
# 28  43.659512 -79.363048    M5A 2B2    ON
# 29  43.666728 -79.381084        NaN    ON

# %%
#delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                        name  \
# 0               Queen's Park Subway Station
# 2          Residences at College Park North
# 5             Crunch Fitness - College Park
# 6                              Queen's Park
# 7                             One Park Lane
# 10                   Physiomed College Park
# 11                   Trinity Bellwoods Park
# 13  GoodLife Fitness Toronto Bloor and Park
# 14                     Bellevue Square Park
# 19                       Canoe Landing Park
# 20                             College Park
# 21                       Battery Park Tower
# 25                      Riverdale Park East
# 26                      Riverdale Park West
# 27                        Osgoode Hall Park
# 28             Regent Park Community Centre
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 2   Residential Building (Apartment / Condo)                   763 Bay St.
# 5                       Gym / Fitness Center              382 Yonge Street
# 6                                       Park               University Ave.
# 7   Residential Building (Apartment / Condo)                 280 Simcoe St
# 10                            Medical Center                  382 Yonge St
# 11                                      Park            1053 Dundas St. W.
# 13                                       Gym                     8 Park Rd
# 14                                      Park  btwn Bellevue & Augusta Ave.
# 19                                      Park             50 Fort York Blvd
# 20                             Shopping Mall                  444 Yonge St
# 21  Residential Building (Apartment / Condo)           50 Lynn Williams St
# 25                                      Park             550 Broadview Ave
# 26                                      Park               500 Gerrard St.
# 27                                      Park                130 Queen St W
# 28                          Community Center               465 Dundas St E
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 2   43.659822 -79.385159    M5G 2R3    ON
# 5   43.659263 -79.382632    M5G 1S8    ON
# 6   43.663946 -79.392180    M5R 2E8    ON
# 7   43.655442 -79.390056    M5T 2Y5    ON
# 10  43.659240 -79.382860    M5B 1S8    ON
# 11  43.647072 -79.413756    M5H 2N2    ON
# 13  43.671302 -79.384691    M4W 3G8    ON
# 14  43.653610 -79.402199    M5T 2N4    ON
# 19  43.638762 -79.397067    M5V 3Z1    ON
# 20  43.661237 -79.383603    M5B 2H4    ON
# 21  43.639024 -79.415510    M6K 3R9    ON
# 25  43.669951 -79.355493    M4K 2P1    ON
# 26  43.666048 -79.360941    M5A 2H3    ON
# 27  43.651105 -79.386269    M5H 2N5    ON
# 28  43.659512 -79.363048    M5A 2B2    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 6             Queen's Park       Park               University Ave.
# 11  Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 14    Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 19      Canoe Landing Park       Park             50 Fort York Blvd
# 25     Riverdale Park East       Park             550 Broadview Ave
# 26     Riverdale Park West       Park               500 Gerrard St.
# 27       Osgoode Hall Park       Park                130 Queen St W
#
#           lat        lng postalCode state
# 6   43.663946 -79.392180    M5R 2E8    ON
# 11  43.647072 -79.413756    M5H 2N2    ON
# 14  43.653610 -79.402199    M5T 2N4    ON
# 19  43.638762 -79.397067    M5V 3Z1    ON
# 25  43.669951 -79.355493    M4K 2P1    ON
# 26  43.666048 -79.360941    M5A 2H3    ON
# 27  43.651105 -79.386269    M5H 2N5    ON

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 2  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4ae29812f964a520288f21e3     309 Spadina Ave.          CA       Toronto
# 2  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 3  4b074bb1f964a52077fb22e3     353 Spadina Ave.          CA       Toronto
# 4  4b266f05f964a520657b24e3      266 Spadina Ave          CA       Toronto
#
#   location.country            location.crossStreet  location.distance  \
# 0           Canada                             NaN                145
# 1           Canada  btwn Dundas St. W & D'Arcy St.                896
# 2           Canada                   at D'Arcy St.                922
# 3           Canada                             NaN                953
# 4           Canada                  at Willison Sq                892
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 2  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 3     [353 Spadina Ave., Toronto ON M5T 2G3, Canada]
# 4  [266 Spadina Ave (at Willison Sq), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 1  [{'label': 'display', 'lat': 43.65386562507761...     43.653866
# 2  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 3  [{'label': 'display', 'lat': 43.65533674412141...     43.655337
# 4  [{'label': 'display', 'lat': 43.6522783893466,...     43.652278
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.385931                   NaN             M5G 1R3             ON
# 1    -79.398334                   NaN             M5T 2E6             ON
# 2    -79.398650     Kensington Market             M5T 2E9             ON
# 3    -79.398897                   NaN             M5T 2G3             ON
# 4    -79.398039                   NaN             M5T 2E4             ON
#
#                               name    referralId venuePage.id
# 0  Hemispheres Restaurant & Bistro  v-1577761257          NaN
# 1          Swatow Restaurant 汕頭小食家  v-1577761257          NaN
# 2           Rol San Restaurant 龍笙棧  v-1577761257          NaN
# 3         New Sky Restaurant 小沙田食家  v-1577761257          NaN
# 4   Goldstone Noodle Restaurant 金石  v-1577761257          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                               name           categories              address  \
# 0  Hemispheres Restaurant & Bistro  American Restaurant  110 Chestnut Street
# 1          Swatow Restaurant 汕頭小食家   Chinese Restaurant     309 Spadina Ave.
# 2           Rol San Restaurant 龍笙棧   Dim Sum Restaurant     323 Spadina Ave.
# 3         New Sky Restaurant 小沙田食家   Chinese Restaurant     353 Spadina Ave.
# 4   Goldstone Noodle Restaurant 金石         Noodle House      266 Spadina Ave
#
#    cc     city country                     crossStreet  distance  \
# 0  CA  Toronto  Canada                             NaN       145
# 1  CA  Toronto  Canada  btwn Dundas St. W & D'Arcy St.       896
# 2  CA  Toronto  Canada                   at D'Arcy St.       922
# 3  CA  Toronto  Canada                             NaN       953
# 4  CA  Toronto  Canada                  at Willison Sq       892
#
#                                     formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 2  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 3     [353 Spadina Ave., Toronto ON M5T 2G3, Canada]
# 4  [266 Spadina Ave (at Willison Sq), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 1  [{'label': 'display', 'lat': 43.65386562507761...  43.653866 -79.398334
# 2  [{'label': 'display', 'lat': 43.65431754076345...  43.654318 -79.398650
# 3  [{'label': 'display', 'lat': 43.65533674412141...  43.655337 -79.398897
# 4  [{'label': 'display', 'lat': 43.6522783893466,...  43.652278 -79.398039
#
#         neighborhood postalCode state                        id
# 0                NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 1                NaN    M5T 2E6    ON  4ae29812f964a520288f21e3
# 2  Kensington Market    M5T 2E9    ON  4ad4c060f964a5207ff720e3
# 3                NaN    M5T 2G3    ON  4b074bb1f964a52077fb22e3
# 4                NaN    M5T 2E4    ON  4b266f05f964a520657b24e3

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 2                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 3                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 4                   Goldstone Noodle Restaurant 金石             Noodle House
# 5                     Aroma Fine Indian Restaurant        Indian Restaurant
# 6                            Victoria's Restaurant               Restaurant
# 7                                   360 Restaurant                 Wine Bar
# 8                           Azure Restaurant & Bar               Restaurant
# 9               Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 10                  The Hot House Restaurant & Bar      American Restaurant
# 11                        Ka Chi Korean Restaurant        Korean Restaurant
# 12                   Green Tea Restaurant Downtown       Chinese Restaurant
# 13              North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 14         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 15                         Victor Restaurant & Bar                      Bar
# 16                     Woodlot Restaurant & Bakery  New American Restaurant
# 17              Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 18                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 19                  Insomnia Restaurant and Lounge               Restaurant
# 20  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 21                 Kyoto House Japanese Restaurant         Sushi Restaurant
# 22               Kensington Cornerstone Restaurant           Breakfast Spot
# 23                               Studio Restaurant           Breakfast Spot
# 24             Richtree Natural Market Restaurants               Restaurant
# 25                    Yueh Tung Chinese Restaurant       Chinese Restaurant
# 26                      Wah Too Seafood Restaurant       Chinese Restaurant
# 27                     Cottage Restaurant & Lounge          Thai Restaurant
# 28                         The Lakeview Restaurant                    Diner
# 29                           ONE Restaurant/Lounge  New American Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 2                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 3                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 4                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 5                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 6               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 7                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 8                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 9                988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 10                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 11                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 12  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 13                   476 Dundas St.  43.653185 -79.396677        NaN    ON
# 14                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 15                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 16              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 17                 280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 18                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 19                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 20            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 21              143 Dundas St. West  43.655381 -79.385270        NaN    ON
# 22               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 23                   389 Church St.  43.661500 -79.379319        M5B    ON
# 24                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 25                126 Elizabeth St.  43.655281 -79.385337        NaN    ON
# 26                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 27                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 28                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 29                116 Yorkville Ave  43.670809 -79.393272        NaN    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 2                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 3                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 4                   Goldstone Noodle Restaurant 金石             Noodle House
# 5                     Aroma Fine Indian Restaurant        Indian Restaurant
# 6                            Victoria's Restaurant               Restaurant
# 7                                   360 Restaurant                 Wine Bar
# 8                           Azure Restaurant & Bar               Restaurant
# 10                  The Hot House Restaurant & Bar      American Restaurant
# 11                        Ka Chi Korean Restaurant        Korean Restaurant
# 12                   Green Tea Restaurant Downtown       Chinese Restaurant
# 14         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 15                         Victor Restaurant & Bar                      Bar
# 16                     Woodlot Restaurant & Bakery  New American Restaurant
# 18                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 19                  Insomnia Restaurant and Lounge               Restaurant
# 20  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 22               Kensington Cornerstone Restaurant           Breakfast Spot
# 23                               Studio Restaurant           Breakfast Spot
# 24             Richtree Natural Market Restaurants               Restaurant
# 26                      Wah Too Seafood Restaurant       Chinese Restaurant
# 27                     Cottage Restaurant & Lounge          Thai Restaurant
# 28                         The Lakeview Restaurant                    Diner
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 2                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 3                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 4                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 5                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 6               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 7                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 8                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 10                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 11                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 12  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 14                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 15                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 16              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 18                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 19                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 20            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 22               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 23                   389 Church St.  43.661500 -79.379319        M5B    ON
# 24                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 26                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 27                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 28                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON

# %% [markdown]
# ## Search For Cafeteria

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
#assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  53bd6dfe498e6c1d3bc9333e                                        NaN
# 3  4ec2b68a8231a83de8c45191                             100 McCaul St.
# 4  556f826b498e07f469e6bf1f                                        NaN
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada                  NaN
# 3          CA       Toronto           Canada         Second Floor
# 4          CA           NaN           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                372  [The Hospital for Sick Children (SickKids), To...
# 1                977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2                260                               [Toronto ON, Canada]
# 3                389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 4                431                                           [Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
# 3  [{'label': 'display', 'lat': 43.65278016892648...     43.652780
# 4  [{'label': 'display', 'lat': 43.65417861938476...     43.654179
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.389443                 NaN             ON
# 3    -79.391762                 NaN             ON
# 4    -79.392555                 NaN            NaN
#
#                             name    referralId
# 0                      Cafeteria  v-1577761443
# 1              Stay Cafeteria 慢走  v-1577761443
# 2  Industrial Alliance Cafeteria  v-1577761443
# 3                 OCAD Cafeteria  v-1577761443
# 4                Dears Cafeteria  v-1577761443

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2  Industrial Alliance Cafeteria             Cafeteria
# 3                 OCAD Cafeteria     College Cafeteria
# 4                Dears Cafeteria          Dessert Shop
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                                        NaN  CA  Toronto  Canada
# 3                             100 McCaul St.  CA  Toronto  Canada
# 4                                        NaN  CA      NaN  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       372  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St       977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2           NaN       260                               [Toronto ON, Canada]
# 3  Second Floor       389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 4           NaN       431                                           [Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...  43.657209 -79.386063
# 1  [{'label': 'display', 'lat': 43.65545427446646...  43.655454 -79.399163
# 2  [{'label': 'display', 'lat': 43.655657, 'lng':...  43.655657 -79.389443
# 3  [{'label': 'display', 'lat': 43.65278016892648...  43.652780 -79.391762
# 4  [{'label': 'display', 'lat': 43.65417861938476...  43.654179 -79.392555
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2        NaN    ON  53bd6dfe498e6c1d3bc9333e
# 3        NaN    ON  4ec2b68a8231a83de8c45191
# 4        NaN   NaN  556f826b498e07f469e6bf1f

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2           Industrial Alliance Cafeteria             Cafeteria
# 3                          OCAD Cafeteria     College Cafeteria
# 4                         Dears Cafeteria          Dessert Shop
# 5                         Sears Cafeteria            Food Court
# 6                 Chestnut Tree Cafeteria             Cafeteria
# 7           De La Salle College Cafeteria     College Cafeteria
# 8                       Robarts Cafeteria     College Cafeteria
# 9                       Med Sci Cafeteria     College Cafeteria
# 10                  Ryerson Hub Cafeteria     College Cafeteria
# 11                     SickKids Cafeteria            Food Court
# 12              Macdonald Block Cafeteria             Cafeteria
# 13  George Brown College St. James Campus     Community College
# 14                          OMP Cafeteria             Cafeteria
# 15                       Rogers Cafeteria            Food Court
# 16                      Choices Cafeteria            Food Court
# 17    Cafeteria, Lawrence Park Collegiate           High School
# 18                       Kasala Cafeteria    African Restaurant
# 19    Cafeteria, Lawrence Park Collegiate           Event Space
# 20                             Marketeria            Restaurant
# 21                                The Hub     College Cafeteria
# 22               Estonian House Cafeteria                  Café
# 23                           CC Cafeteria     College Cafeteria
# 24                          Innis College        Student Center
# 25                             Radio Cafe            Food Court
# 26     Lawrence Park Collegiate Cafeteria           High School
# 27                           L5 Cafeteria      Cuban Restaurant
# 28  6th Floor Cafeteria 12 Concorde Place                  Café
# 29                      Glendon Cafeteria     College Cafeteria
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                                         NaN  43.655657 -79.389443
# 3                              100 McCaul St.  43.652780 -79.391762
# 4                                         NaN  43.654179 -79.392555
# 5                                       Yonge  43.656038 -79.380672
# 6                          89 Chestnut Street  43.648231 -79.384045
# 7                          131 Farnham Avenue  43.683003 -79.397815
# 8                          130 St. George St.  43.664864 -79.399766
# 9                                         NaN  43.660260 -79.392977
# 10                           350 Victoria St.  43.658475 -79.377653
# 11                      555 University Avenue  43.657584 -79.375652
# 12                                        NaN  43.663212 -79.388062
# 13                          200 King St. East  43.651366 -79.370158
# 14                           1 Mount Pleasant  43.669801 -79.379790
# 15                                        NaN  43.669904 -79.379748
# 16                         200 Bloor Street E  43.671411 -79.381849
# 17                                        NaN  43.721732 -79.409600
# 18                                      Bloor  43.660759 -79.424018
# 19                                        NaN  43.723286 -79.412222
# 20                                30 Bond St.  43.653585 -79.378843
# 21                           350 Victoria St.  43.658585 -79.380622
# 22                       958 Broadview avenue  43.681763 -79.358246
# 23                             951 Carlaw Ave  43.684631 -79.348862
# 24                               2 Sussex Ave  43.665556 -79.399298
# 25                          333 Bloor st east  43.671696 -79.380617
# 26                                        NaN  43.722757 -79.413734
# 27                                        NaN  43.723019 -79.345012
# 28                          12 Concorde Place  43.721861 -79.329339
# 29                           2275 Bayview Ave  43.727383 -79.378080
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2         NaN    ON
# 3         NaN    ON
# 4         NaN   NaN
# 5         NaN    ON
# 6         NaN    ON
# 7     M4V 1H7    ON
# 8         NaN    ON
# 9         NaN    ON
# 10        NaN    ON
# 11        NaN    ON
# 12        NaN   NaN
# 13        NaN    ON
# 14        NaN    ON
# 15        NaN    ON
# 16        NaN    ON
# 17        NaN   NaN
# 18        NaN   NaN
# 19        NaN   NaN
# 20    M5B 1W8    ON
# 21    M5B 2K3    ON
# 22        NaN    ON
# 23        NaN    ON
# 24    M5S 1J5    ON
# 25        NaN    ON
# 26        NaN    ON
# 27        NaN   NaN
# 28    m3c 3k7    ON
# 29        NaN    ON

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name         categories  \
# 1                       Stay Cafeteria 慢走   Asian Restaurant
# 7           De La Salle College Cafeteria  College Cafeteria
# 20                             Marketeria         Restaurant
# 21                                The Hub  College Cafeteria
# 24                          Innis College     Student Center
# 28  6th Floor Cafeteria 12 Concorde Place               Café
#
#                address        lat        lng postalCode state
# 1      388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 7   131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 20         30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 21    350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 24        2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 28   12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %% [markdown]
# ## Search For Shopping Store

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id    location.address location.cc location.city  \
# 0  4ad4c062f964a520fcf720e3     280 Spadina Ave          CA       Toronto
# 1  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
# 2  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 3  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 4  4b83d653f964a520d91231e3   461 King St. West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada       at Dundas St W                897
# 1           Canada  btwn Queen & Dundas                532
# 2           Canada    btw York & Bay St                908
# 3           Canada    Queen Street West                688
# 4           Canada                  NaN                974
#
#                            location.formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...     43.652774
# 1                                                NaN     43.653594
# 2  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 4  [{'label': 'display', 'lat': 43.64795765580337...     43.647958
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.398222                            NaN             M5T 3A5
# 1    -79.380611  Downtown Toronto, Toronto, ON             M5B 2H1
# 2    -79.380932                            NaN             M5K 1A1
# 3    -79.379192                            NaN             M5C 2L7
# 4    -79.396006                            NaN             M5V 1K4
#
#   location.state                                        name    referralId
# 0             ON                Dragon City Shopping Mall 龍城  v-1577761540
# 1             ON                     CF Toronto Eaton Centre  v-1577761540
# 2             ON                TD Centre Shopping Concourse  v-1577761540
# 3             ON  Saks Fifth Avenue Club - Personal Shopping  v-1577761540
# 4             ON             Yellow Pages - RedFlagDeals.com  v-1577761540

# %%
#keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address  cc     city country          crossStreet  distance  \
# 0     280 Spadina Ave  CA  Toronto  Canada       at Dundas St W       897
# 1        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       532
# 2  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       908
# 3    176 Yonge Street  CA  Toronto  Canada    Queen Street West       688
# 4   461 King St. West  CA  Toronto  Canada                  NaN       974
#
#                                     formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...  43.652774 -79.398222
# 1                                                NaN  43.653594 -79.380611
# 2  [{'label': 'display', 'lat': 43.64718424611984...  43.647184 -79.380932
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...  43.651810 -79.379192
# 4  [{'label': 'display', 'lat': 43.64795765580337...  43.647958 -79.396006
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5T 3A5    ON  4ad4c062f964a520fcf720e3
# 1  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3
# 2                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3
# 3                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 4                            NaN    M5V 1K4    ON  4b83d653f964a520d91231e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1        220 Yonge St  43.653594 -79.380611    M5B 2H1    ON
# 2  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 3    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 4   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.653594
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380611    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %% [markdown]
# ## Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                      name         categories  \
# 0           Sheraton Centre Toronto Hotel              Hotel
# 1                          Grand Ballroom        Event Space
# 2                       Stay Cafeteria 慢走   Asian Restaurant
# 3           De La Salle College Cafeteria  College Cafeteria
# 4                              Marketeria         Restaurant
# 5                                 The Hub  College Cafeteria
# 6                           Innis College     Student Center
# 7   6th Floor Cafeteria 12 Concorde Place               Café
# 8            Dragon City Shopping Mall 龍城      Shopping Mall
# 9                 CF Toronto Eaton Centre      Shopping Mall
# 10           TD Centre Shopping Concourse      Shopping Mall
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 1         123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 2         388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 3      131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 4             30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 5        350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 6            2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 7       12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 8         280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 9            220 Yonge St  43.653594 -79.380611    M5B 2H1    ON
# 10     66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name               categories  \
# 0                                     Queen's Park                     Park
# 1                           Trinity Bellwoods Park                     Park
# 2                             Bellevue Square Park                     Park
# 3                               Canoe Landing Park                     Park
# 4                              Riverdale Park East                     Park
# 5                              Riverdale Park West                     Park
# 6                                Osgoode Hall Park                     Park
# 7                  Hemispheres Restaurant & Bistro      American Restaurant
# 8                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 9                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 10                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 11                  Goldstone Noodle Restaurant 金石             Noodle House
# 12                    Aroma Fine Indian Restaurant        Indian Restaurant
# 13                           Victoria's Restaurant               Restaurant
# 14                                  360 Restaurant                 Wine Bar
# 15                          Azure Restaurant & Bar               Restaurant
# 16                  The Hot House Restaurant & Bar      American Restaurant
# 17                        Ka Chi Korean Restaurant        Korean Restaurant
# 18                   Green Tea Restaurant Downtown       Chinese Restaurant
# 19         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 20                         Victor Restaurant & Bar                      Bar
# 21                     Woodlot Restaurant & Bakery  New American Restaurant
# 22                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 23                  Insomnia Restaurant and Lounge               Restaurant
# 24  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 25               Kensington Cornerstone Restaurant           Breakfast Spot
# 26                               Studio Restaurant           Breakfast Spot
# 27             Richtree Natural Market Restaurants               Restaurant
# 28                      Wah Too Seafood Restaurant       Chinese Restaurant
# 29                     Cottage Restaurant & Lounge          Thai Restaurant
# 30                         The Lakeview Restaurant                    Diner
# 31                               Stay Cafeteria 慢走         Asian Restaurant
# 32                   De La Salle College Cafeteria        College Cafeteria
# 33                                      Marketeria               Restaurant
# 34                                         The Hub        College Cafeteria
# 35                                   Innis College           Student Center
# 36           6th Floor Cafeteria 12 Concorde Place                     Café
#
#                             address        lat        lng postalCode state
# 0                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 1                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 2      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 3                 50 Fort York Blvd  43.638762 -79.397067    M5V 3Z1    ON
# 4                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 5                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 6                    130 Queen St W  43.651105 -79.386269    M5H 2N5    ON
# 7               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 8                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 9                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 10                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 11                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 12                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 13              37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 14                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 15                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 16                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 17                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 18  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 19                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 20                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 21              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 22                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 23                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 24            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 25               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 26                   389 Church St.  43.661500 -79.379319        M5B    ON
# 27                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 28                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 29                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 30                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 31                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 32               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 33                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 34                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 35                     2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 36                12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
